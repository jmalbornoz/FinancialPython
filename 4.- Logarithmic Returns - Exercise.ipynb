# %% [markdown]
# ## Logarithmic Returns

# %%
# Render our plots inline
# %matplotlib inline
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
MSFT = pd.read_csv('MSFT_2000_2017.csv', index_col = 'Date')
MSFT.head(5)
# Out:
#                 Open     High      Low     Close  Adj Close    Volume
# Date
# 1999-12-31  58.75000  58.8750  58.1250  58.37500  38.771053  12517600
# 2000-01-03  58.68750  59.3125  56.0000  58.28125  38.708794  53228400
# 2000-01-04  56.78125  58.5625  56.1250  56.31250  37.401215  54119000
# 2000-01-05  55.56250  58.1875  54.6875  56.90625  37.795563  64059600
# 2000-01-06  56.09375  56.9375  54.1875  55.00000  36.529484  54976600

# %%
MSFT['Adj Close'].plot(figsize=(8, 5))

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT['log_return'] = np.log(MSFT['Adj Close'] / MSFT['Adj Close'].shift(1))

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(8, 5))

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
avg_returns_d = MSFT['log_return'].mean()
avg_returns_d
# Out:
# 0.00017519780079971006

# %%
avg_returns_a = avg_returns_d*250
avg_returns_a
# Out:
# 0.043799450199927516

# %% [markdown]
# Print the result in a presentable form.

# %%
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# 4.38 %

# %% [markdown]
# ****

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)

# %%
UIS = wb.DataReader('UIS', data_source='iex', start='2015-1-1')

# %%
UIS.tail()
# Out:
#              open    high   low  close   volume
# date
# 2019-05-09   9.98  10.010  9.68   9.90  1097321
# 2019-05-10   9.81  10.300  9.81  10.26  1001954
# 2019-05-13  10.00  10.060  9.71   9.85  1029958
# 2019-05-14   9.87   9.909  9.73   9.83   563851
# 2019-05-15   9.70   9.890  9.70   9.83   521007

# %%
UIS['close'].plot(figsize=(8, 5))

# %%
UIS['log_return'] = np.log(UIS['close'] / UIS['close'].shift(1))

# %%
UIS['log_return'].plot(figsize=(8, 5))

# %%
avg_returns_d = UIS['log_return'].mean()
avg_returns_d
# Out:
# -0.0009818365940975106

# %%
avg_returns_a = avg_returns_d*250
avg_returns_a
# Out:
# -0.24545914852437764

# %%
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# -24.55 %
