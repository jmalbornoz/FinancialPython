# %% [markdown]
# ## Logarithmic Returns

# %%
# Render our plots inline
# %matplotlib inline
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
MSFT = wb.DataReader('MSFT', data_source='iex', start='2015-1-1')
MSFT.head(5)
# Out:
#                open     high      low    close    volume
# date
# 2015-01-02  42.1719  42.8588  42.0634  42.2623  27913852
# 2015-01-05  41.9098  42.2351  41.8013  41.8691  39673865
# 2015-01-06  41.9188  42.2523  41.1596  41.2590  36447854
# 2015-01-07  41.5573  41.9911  41.1144  41.7832  29114061
# 2015-01-08  42.2532  43.1569  42.2261  43.0124  29645202

# %%
MSFT['close'].plot(figsize=(8,5))

# %% [markdown]
# ### Log Returns

# %% [markdown]
# $$
# ln(\frac{P_t}{P_{t-1}})
# $$

# %% [markdown]
# Calculate the Log returns for Microsoft.

# %%
MSFT['log_return'] = np.log(MSFT['close']/MSFT['close'].shift(1))

# %% [markdown]
# Plot the results on a graph.

# %%
MSFT['log_return'].plot(figsize=(8,5))

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
avg_returns_d = MSFT['log_return'].mean()
avg_returns_d
# Out:
# 0.0009950320481045697

# %%
avg_returns_a = avg_returns_d*250
avg_returns_a
# Out:
# 0.24875801202614242

# %% [markdown]
# Print the result in a presentable form.

# %%
print((str(round(avg_returns_a, 4) * 100) + ' %'))
# Out:
# 24.88 %

# %% [markdown]
# ****

# %% [markdown]
# Repeat this exercise for any stock of interest to you. :)

# %%
AMZN = wb.DataReader('AMZN', data_source='iex', start='2015-1-1')
AMZN.head(5)
# Out:
#               open    high       low   close   volume
# date
# 2015-01-02  312.58  314.75  306.9601  308.52  2788101
# 2015-01-05  307.01  308.38  300.8500  302.19  2774231
# 2015-01-06  302.24  303.00  292.3800  295.29  3519034
# 2015-01-07  297.50  301.28  295.3300  298.42  2640349
# 2015-01-08  300.32  303.14  296.1100  300.46  3088398

# %%
AMZN['close'].plot(figsize=(8,5))

# %%
AMZN['log_return'] = np.log(AMZN['close']/AMZN['close'].shift(1))

# %%
AMZN['log_return'].plot(figsize=(8,5))

# %% [markdown]
# Estimate the daily and the annual mean of the obtained log returns.

# %%
avg_returns_d = AMZN['log_return'].mean()
avg_returns_d
# Out:
# 0.0016416410045776884

# %%
avg_returns_a = avg_returns_d*250
avg_returns_a
# Out:
# 0.4104102511444221

# %% [markdown]
# Print the result in a presentable form.

# %%
print((str(round(avg_returns_a, 4) * 100) + ' %'))
# Out:
# 41.04 %
